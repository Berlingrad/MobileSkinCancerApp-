# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from datetime import datetime
import hashlib
import os.path
import random
import re
import struct
import sys
import tarfile

import numpy as np
from six.moves import urllib
import tensorflow as tf

from tensorflow.python.framework import graph_util
from tensorflow.python.framework import tensor_shape
from tensorflow.python.platform import gfile
from tensorflow.python.util import compat

# %%
import os
image_dir = "TrainingImages"
output_graph = "skin_output_graph.pb"
output_labels = "skin_output_labels.txt"
summaries_dir = "/tmp/output_labels.txt"
how_many_training_steps = 500
learning_rate = 0.01
testing_percentage = 10
validation_percentage = 10
eval_step_interval = 10
train_batch_size = 100
test_batch_size = -1
validation_batch_size = 100
print_misclassified_test_images = False
model_dir = os.path.join('inception')
bottleneck_dir = "sk_bottlenecks"
final_tensor_name = "final_result"
flip_left_right = False
random_crop = 0
random_scale = 0
random_brightness = 0
DATA_URL = 'http://download.tensorflow.org/models/image/imagenet/inception-2015-12-05.tgz'

# pylint: enable=line-too-long
BOTTLENECK_TENSOR_NAME = 'pool_3/_reshape:0'
BOTTLENECK_TENSOR_SIZE = 2048
MODEL_INPUT_WIDTH = 299
MODEL_INPUT_HEIGHT = 299
MODEL_INPUT_DEPTH = 3
JPEG_DATA_TENSOR_NAME = 'DecodeJpeg/contents:0'
RESIZED_INPUT_TENSOR_NAME = 'ResizeBilinear:0'
MAX_NUM_IMAGES_PER_CLASS = 2 ** 27 - 1  # ~134M

# %%
def create_image_lists(image_dir, testing_percentage, validation_percentage):
  if not gfile.Exists(image_dir):
    print("Image directory '" + image_dir + "' not found.")
    return None
  result = {}
  sub_dirs = [x[0] for x in gfile.Walk(image_dir)]
  # The root directory comes first, so skip it.
  is_root_dir = True
  for sub_dir in sub_dirs:
    if is_root_dir:
      is_root_dir = False
      continue
    extensions = ['jpg', 'jpeg', 'JPG', 'JPEG']
    file_list = []
    dir_name = os.path.basename(sub_dir)
    if dir_name == image_dir:
      continue
    print("Looking for images in '" + dir_name + "'")
    for extension in extensions:
      file_glob = os.path.join(image_dir, dir_name, '*.' + extension)
      file_list.extend(gfile.Glob(file_glob))
    if not file_list:
      print('No files found')
      continue
    if len(file_list) < 20:
      print('WARNING: Folder has less than 20 images, which may cause issues.')
    elif len(file_list) > MAX_NUM_IMAGES_PER_CLASS:
      print('WARNING: Folder {} has more than {} images. Some images will '
            'never be selected.'.format(dir_name, MAX_NUM_IMAGES_PER_CLASS))
    label_name = re.sub(r'[^a-z0-9]+', ' ', dir_name.lower())
    training_images = []
    testing_images = []
    validation_images = []
    for file_name in file_list:
      base_name = os.path.basename(file_name)
      # We want to ignore anything after '_nohash_' in the file name when
      # deciding which set to put an image in, the data set creator has a way of
      # grouping photos that are close variations of each other. For example
      # this is used in the plant disease data set to group multiple pictures of
      # the same leaf.
      hash_name = re.sub(r'_nohash_.*$', '', file_name)
      # This looks a bit magical, but we need to decide whether this file should
      # go into the training, testing, or validation sets, and we want to keep
      # existing files in the same set even if more files are subsequently
      # added.
      # To do that, we need a stable way of deciding based on just the file name
      # itself, so we do a hash of that and then use that to generate a
      # probability value that we use to assign it.
      hash_name_hashed = hashlib.sha1(compat.as_bytes(hash_name)).hexdigest()
      percentage_hash = ((int(hash_name_hashed, 16) %
                          (MAX_NUM_IMAGES_PER_CLASS + 1)) *
                         (100.0 / MAX_NUM_IMAGES_PER_CLASS))
      if percentage_hash < validation_percentage:
        validation_images.append(base_name)
      elif percentage_hash < (testing_percentage + validation_percentage):
        testing_images.append(base_name)
      else:
        training_images.append(base_name)
    result[label_name] = {
        'dir': dir_name,
        'training': training_images,
        'testing': testing_images,
        'validation': validation_images,
    }
  return result

# %%
def get_image_path(image_lists, label_name, index, image_dir, category):
  if label_name not in image_lists:
    tf.logging.fatal('Label does not exist %s.', label_name)
  label_lists = image_lists[label_name]
  if category not in label_lists:
    tf.logging.fatal('Category does not exist %s.', category)
  category_list = label_lists[category]
  if not category_list:
    tf.logging.fatal('Label %s has no images in the category %s.',
                     label_name, category)
  mod_index = index % len(category_list)
  base_name = category_list[mod_index]
  sub_dir = label_lists['dir']
  full_path = os.path.join(image_dir, sub_dir, base_name)
  return full_path

# %%
def get_bottleneck_path(image_lists, label_name, index, bottleneck_dir,
                        category):
  
  return get_image_path(image_lists, label_name, index, bottleneck_dir,
                        category) + '.txt'

# %%
def create_inception_graph():
  with tf.Session() as sess:
    model_filename = os.path.join(
        model_dir, 'classify_image_graph_def.pb')
    with gfile.FastGFile(model_filename, 'rb') as f:
      graph_def = tf.GraphDef()
      graph_def.ParseFromString(f.read())
      bottleneck_tensor, jpeg_data_tensor, resized_input_tensor = (
          tf.import_graph_def(graph_def, name='', return_elements=[
              BOTTLENECK_TENSOR_NAME, JPEG_DATA_TENSOR_NAME,
              RESIZED_INPUT_TENSOR_NAME]))
  return sess.graph, bottleneck_tensor, jpeg_data_tensor, resized_input_tensor

# %%
def run_bottleneck_on_image(sess, image_data, image_data_tensor,
                            bottleneck_tensor):
  bottleneck_values = sess.run(
      bottleneck_tensor,
      {image_data_tensor: image_data})
  bottleneck_values = np.squeeze(bottleneck_values)
  return bottleneck_values

# %%
def maybe_download_and_extract():
  dest_directory = model_dir
  if not os.path.exists(dest_directory):
    os.makedirs(dest_directory)
  filename = DATA_URL.split('/')[-1]
  filepath = os.path.join(dest_directory, filename)
  if not os.path.exists(filepath):

    def _progress(count, block_size, total_size):
      sys.stdout.write('\r>> Downloading %s %.1f%%' %
                       (filename,
                        float(count * block_size) / float(total_size) * 100.0))
      sys.stdout.flush()

    filepath, _ = urllib.request.urlretrieve(DATA_URL,
                                             filepath,
                                             _progress)
    print()
    statinfo = os.stat(filepath)
    print('Successfully downloaded', filename, statinfo.st_size, 'bytes.')
  tarfile.open(filepath, 'r:gz').extractall(dest_directory)

# %%
def ensure_dir_exists(dir_name):
  if not os.path.exists(dir_name):
    os.makedirs(dir_name)

# %%
def write_list_of_floats_to_file(list_of_floats , file_path):
  s = struct.pack('d' * BOTTLENECK_TENSOR_SIZE, *list_of_floats)
  with open(file_path, 'wb') as f:
    f.write(s)

# %%
def read_list_of_floats_from_file(file_path):

  with open(file_path, 'rb') as f:
    s = struct.unpack('d' * BOTTLENECK_TENSOR_SIZE, f.read())
    return list(s)

# %%
bottleneck_path_2_bottleneck_values = {}

def create_bottleneck_file(bottleneck_path, image_lists, label_name, index,
                           image_dir, category, sess, jpeg_data_tensor, bottleneck_tensor):
  print('Creating bottleneck at ' + bottleneck_path)
  image_path = get_image_path(image_lists, label_name, index, image_dir, category)
  if not gfile.Exists(image_path):
    tf.logging.fatal('File does not exist %s', image_path)
  image_data = gfile.FastGFile(image_path, 'rb').read()
  bottleneck_values = run_bottleneck_on_image(sess, image_data, jpeg_data_tensor, bottleneck_tensor)
  bottleneck_string = ','.join(str(x) for x in bottleneck_values)
  with open(bottleneck_path, 'w') as bottleneck_file:
    bottleneck_file.write(bottleneck_string)

# %%
def get_or_create_bottleneck(sess, image_lists, label_name, index, image_dir,
                             category, bottleneck_dir, jpeg_data_tensor,
                             bottleneck_tensor):
  label_lists = image_lists[label_name]
  sub_dir = label_lists['dir']
  sub_dir_path = os.path.join(bottleneck_dir, sub_dir)
  ensure_dir_exists(sub_dir_path)
  bottleneck_path = get_bottleneck_path(image_lists, label_name, index, bottleneck_dir, category)
  if not os.path.exists(bottleneck_path):
    create_bottleneck_file(bottleneck_path, image_lists, label_name, index, image_dir, category, sess, jpeg_data_tensor, bottleneck_tensor)
  with open(bottleneck_path, 'r') as bottleneck_file:
    bottleneck_string = bottleneck_file.read()
  did_hit_error = False
  try:
    bottleneck_values = [float(x) for x in bottleneck_string.split(',')]
  except:
    print("Invalid float found, recreating bottleneck")
    did_hit_error = True
  if did_hit_error:
    create_bottleneck_file(bottleneck_path, image_lists, label_name, index, image_dir, category, sess, jpeg_data_tensor, bottleneck_tensor)
    with open(bottleneck_path, 'r') as bottleneck_file:
      bottleneck_string = bottleneck_file.read()
    # Allow exceptions to propagate here, since they shouldn't happen after a fresh creation
    bottleneck_values = [float(x) for x in bottleneck_string.split(',')]
  return bottleneck_values

# %%
def cache_bottlenecks(sess, image_lists, image_dir, bottleneck_dir,
                      jpeg_data_tensor, bottleneck_tensor):
  how_many_bottlenecks = 0
  ensure_dir_exists(bottleneck_dir)
  for label_name, label_lists in image_lists.items():
    for category in ['training', 'testing', 'validation']:
      category_list = label_lists[category]
      for index, unused_base_name in enumerate(category_list):
        get_or_create_bottleneck(sess, image_lists, label_name, index,
                                 image_dir, category, bottleneck_dir,
                                 jpeg_data_tensor, bottleneck_tensor)

        how_many_bottlenecks += 1
        if how_many_bottlenecks % 100 == 0:
          print(str(how_many_bottlenecks) + ' bottleneck files created.')

# %%
def get_random_cached_bottlenecks(sess, image_lists, how_many, category,
                                  bottleneck_dir, image_dir, jpeg_data_tensor,
                                  bottleneck_tensor):
  class_count = len(image_lists.keys())
  bottlenecks = []
  ground_truths = []
  filenames = []
  if how_many >= 0:
    # Retrieve a random sample of bottlenecks.
    for unused_i in range(how_many):
      label_index = random.randrange(class_count)
      label_name = list(image_lists.keys())[label_index]
      image_index = random.randrange(MAX_NUM_IMAGES_PER_CLASS + 1)
      image_name = get_image_path(image_lists, label_name, image_index,
                                  image_dir, category)
      bottleneck = get_or_create_bottleneck(sess, image_lists, label_name,
                                            image_index, image_dir, category,
                                            bottleneck_dir, jpeg_data_tensor,
                                            bottleneck_tensor)
      ground_truth = np.zeros(class_count, dtype=np.float32)
      ground_truth[label_index] = 1.0
      bottlenecks.append(bottleneck)
      ground_truths.append(ground_truth)
      filenames.append(image_name)
  else:
    # Retrieve all bottlenecks.
    for label_index, label_name in enumerate(image_lists.keys()):
      for image_index, image_name in enumerate(
          image_lists[label_name][category]):
        image_name = get_image_path(image_lists, label_name, image_index,
                                    image_dir, category)
        bottleneck = get_or_create_bottleneck(sess, image_lists, label_name,
                                              image_index, image_dir, category,
                                              bottleneck_dir, jpeg_data_tensor,
                                              bottleneck_tensor)
        ground_truth = np.zeros(class_count, dtype=np.float32)
        ground_truth[label_index] = 1.0
        bottlenecks.append(bottleneck)
        ground_truths.append(ground_truth)
        filenames.append(image_name)
  return bottlenecks, ground_truths, filenames

# %%
def get_random_distorted_bottlenecks(
    sess, image_lists, how_many, category, image_dir, input_jpeg_tensor,
    distorted_image, resized_input_tensor, bottleneck_tensor):

  class_count = len(image_lists.keys())
  bottlenecks = []
  ground_truths = []
  for unused_i in range(how_many):
    label_index = random.randrange(class_count)
    label_name = list(image_lists.keys())[label_index]
    image_index = random.randrange(MAX_NUM_IMAGES_PER_CLASS + 1)
    image_path = get_image_path(image_lists, label_name, image_index, image_dir,
                                category)
    if not gfile.Exists(image_path):
      tf.logging.fatal('File does not exist %s', image_path)
    jpeg_data = gfile.FastGFile(image_path, 'rb').read()
    # Note that we materialize the distorted_image_data as a numpy array before
    # sending running inference on the image. This involves 2 memory copies and
    # might be optimized in other implementations.
    distorted_image_data = sess.run(distorted_image,
                                    {input_jpeg_tensor: jpeg_data})
    bottleneck = run_bottleneck_on_image(sess, distorted_image_data,
                                         resized_input_tensor,
                                         bottleneck_tensor)
    ground_truth = np.zeros(class_count, dtype=np.float32)
    ground_truth[label_index] = 1.0
    bottlenecks.append(bottleneck)
    ground_truths.append(ground_truth)
  return bottlenecks, ground_truths

# %%
def should_distort_images(flip_left_right, random_crop, random_scale,
                          random_brightness):
  return (flip_left_right or (random_crop != 0) or (random_scale != 0) or
          (random_brightness != 0))

# %% [markdown]
# The following function creates the operations to apply the specified distortions.
#   During training it can help to improve the results if we run the images
#   through simple distortions like crops, scales, and flips. These reflect the
#   kind of variations we expect in the real world, and so can help train the
#   model to cope with natural data more effectively. Here we take the supplied
#   parameters and construct a network of operations to apply them to an image.
#   Cropping
#   ~~~~~~~~
#   Cropping is done by placing a bounding box at a random position in the full
#   image. The cropping parameter controls the size of that box relative to the
#   input image. If it's zero, then the box is the same size as the input and no
#   cropping is performed. If the value is 50%, then the crop box will be half the
#   width and height of the input. In a diagram it looks like this:
#   <       width         >
#   +---------------------+
#   |                     |
#   |   width - crop%     |
#   |    <      >         |
#   |    +------+         |
#   |    |      |         |
#   |    |      |         |
#   |    |      |         |
#   |    +------+         |
#   |                     |
#   |                     |
#   +---------------------+
#   Scaling
#   ~~~~~~~
#   Scaling is a lot like cropping, except that the bounding box is always
#   centered and its size varies randomly within the given range. For example if
#   the scale percentage is zero, then the bounding box is the same size as the
#   input and no scaling is applied. If it's 50%, then the bounding box will be in
#   a random range between half the width and height and full size.
#   Args:
#     flip_left_right: Boolean whether to randomly mirror images horizontally.
#     random_crop: Integer percentage setting the total margin used around the
#     crop box.
#     random_scale: Integer percentage of how much to vary the scale by.
#     random_brightness: Integer range to randomly multiply the pixel values by.
#     graph.
#   Returns:
#     The jpeg input layer and the distorted result tensor.

# %%
def add_input_distortions(flip_left_right, random_crop, random_scale,
                          random_brightness):
  
  jpeg_data = tf.placeholder(tf.string, name='DistortJPGInput')
  decoded_image = tf.image.decode_jpeg(jpeg_data, channels=MODEL_INPUT_DEPTH)
  decoded_image_as_float = tf.cast(decoded_image, dtype=tf.float32)
  decoded_image_4d = tf.expand_dims(decoded_image_as_float, 0)
  margin_scale = 1.0 + (random_crop / 100.0)
  resize_scale = 1.0 + (random_scale / 100.0)
  margin_scale_value = tf.constant(margin_scale)
  resize_scale_value = tf.random_uniform(tensor_shape.scalar(),
                                         minval=1.0,
                                         maxval=resize_scale)
  scale_value = tf.multiply(margin_scale_value, resize_scale_value)
  precrop_width = tf.multiply(scale_value, MODEL_INPUT_WIDTH)
  precrop_height = tf.multiply(scale_value, MODEL_INPUT_HEIGHT)
  precrop_shape = tf.stack([precrop_height, precrop_width])
  precrop_shape_as_int = tf.cast(precrop_shape, dtype=tf.int32)
  precropped_image = tf.image.resize_bilinear(decoded_image_4d,
                                              precrop_shape_as_int)
  precropped_image_3d = tf.squeeze(precropped_image, squeeze_dims=[0])
  cropped_image = tf.random_crop(precropped_image_3d,
                                 [MODEL_INPUT_HEIGHT, MODEL_INPUT_WIDTH,
                                  MODEL_INPUT_DEPTH])
  if flip_left_right:
    flipped_image = tf.image.random_flip_left_right(cropped_image)
  else:
    flipped_image = cropped_image
  brightness_min = 1.0 - (random_brightness / 100.0)
  brightness_max = 1.0 + (random_brightness / 100.0)
  brightness_value = tf.random_uniform(tensor_shape.scalar(),
                                       minval=brightness_min,
                                       maxval=brightness_max)
  brightened_image = tf.multiply(flipped_image, brightness_value)
  distort_result = tf.expand_dims(brightened_image, 0, name='DistortResult')
  return jpeg_data, distort_result

# %% [markdown]
# Attach a lot of summaries to a Tensor (for TensorBoard visualization).

# %%
def variable_summaries(var):
  
  with tf.name_scope('summaries'):
    mean = tf.reduce_mean(var)
    tf.summary.scalar('mean', mean)
    with tf.name_scope('stddev'):
      stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
    tf.summary.scalar('stddev', stddev)
    tf.summary.scalar('max', tf.reduce_max(var))
    tf.summary.scalar('min', tf.reduce_min(var))
    tf.summary.histogram('histogram', var)

# %% [markdown]
# The following function adds a new softmax and fully-connected layer for training.
#   We need to retrain the top layer to identify our new classes, so this function
#   adds the right operations to the graph, along with some variables to hold the
#   weights, and then sets up all the gradients for the backward pass.
#   The set up for the softmax and fully-connected layers is based on:
#   https://tensorflow.org/versions/master/tutorials/mnist/beginners/index.html
#   Args:
#     class_count: Integer of how many categories of things we're trying to
#     recognize.
#     final_tensor_name: Name string for the new final node that produces results.
#     bottleneck_tensor: The output of the main CNN graph.
#   Returns:
#     The tensors for the training and cross entropy results, and tensors for the
#     bottleneck input and ground truth input.

# %%
def add_final_training_ops(class_count, final_tensor_name, bottleneck_tensor):
  
  with tf.name_scope('input'):
    bottleneck_input = tf.placeholder_with_default(
        bottleneck_tensor, shape=[None, BOTTLENECK_TENSOR_SIZE],
        name='BottleneckInputPlaceholder')

    ground_truth_input = tf.placeholder(tf.float32,
                                        [None, class_count],
                                        name='GroundTruthInput')

  # Organizing the following ops as `final_training_ops` so they're easier
  # to see in TensorBoard
  layer_name = 'final_training_ops'
  with tf.name_scope(layer_name):
    with tf.name_scope('weights'):
      layer_weights = tf.Variable(tf.truncated_normal([BOTTLENECK_TENSOR_SIZE, class_count], stddev=0.001), name='final_weights')
      variable_summaries(layer_weights)
    with tf.name_scope('biases'):
      layer_biases = tf.Variable(tf.zeros([class_count]), name='final_biases')
      variable_summaries(layer_biases)
    with tf.name_scope('Wx_plus_b'):
      logits = tf.matmul(bottleneck_input, layer_weights) + layer_biases
      tf.summary.histogram('pre_activations', logits)

  final_tensor = tf.nn.softmax(logits, name=final_tensor_name)
  tf.summary.histogram('activations', final_tensor)

  with tf.name_scope('cross_entropy'):
    cross_entropy = tf.nn.softmax_cross_entropy_with_logits(
        labels=ground_truth_input, logits=logits)
    with tf.name_scope('total'):
      cross_entropy_mean = tf.reduce_mean(cross_entropy)
  tf.summary.scalar('cross_entropy', cross_entropy_mean)

  with tf.name_scope('train'):
    train_step = tf.train.GradientDescentOptimizer(learning_rate).minimize(
        cross_entropy_mean)

  return (train_step, cross_entropy_mean, bottleneck_input, ground_truth_input,
          final_tensor)

# %% [markdown]
# The following function inserts the operations we need to evaluate the accuracy of our results.
#   Args:
#     result_tensor: The new final node that produces results.
#     ground_truth_tensor: The node we feed ground truth data
#     into.
#   Returns:
#     Tuple of (evaluation step, prediction).

# %%
def add_evaluation_step(result_tensor, ground_truth_tensor):

  with tf.name_scope('accuracy'):
    with tf.name_scope('correct_prediction'):
      prediction = tf.argmax(result_tensor, 1)
      correct_prediction = tf.equal(
          prediction, tf.argmax(ground_truth_tensor, 1))
    with tf.name_scope('accuracy'):
      evaluation_step = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
  tf.summary.scalar('accuracy', evaluation_step)
  return evaluation_step, prediction

# %% [markdown]
# Main function :

# %%
# Setup the directory we'll write summaries to for TensorBoard
if tf.gfile.Exists(summaries_dir):
    tf.gfile.DeleteRecursively(summaries_dir)
tf.gfile.MakeDirs(summaries_dir)

# Set up the pre-trained graph.
maybe_download_and_extract()
graph, bottleneck_tensor, jpeg_data_tensor, resized_image_tensor = (
      create_inception_graph())

# Look at the folder structure, and create lists of all the images.
image_lists = create_image_lists(image_dir, testing_percentage,
                                   validation_percentage)
class_count = len(image_lists.keys())
if class_count == 0:
    print('No valid folders of images found at ' + image_dir)
if class_count == 1:
    print('Only one valid folder of images found at ' + image_dir +
          ' - multiple classes are needed for classification.')
# See if the command-line flags mean we're applying any distortions.
do_distort_images = should_distort_images(
      flip_left_right, random_crop, random_scale,
      random_brightness)
sess = tf.Session()

if do_distort_images:
    # We will be applying distortions, so setup the operations we'll need.
    distorted_jpeg_data_tensor, distorted_image_tensor = add_input_distortions(
        flip_left_right, random_crop, random_scale,
        random_brightness)
else:
    # We'll make sure we've calculated the 'bottleneck' image summaries and
    # cached them on disk.
    cache_bottlenecks(sess, image_lists, image_dir, bottleneck_dir,
                      jpeg_data_tensor, bottleneck_tensor)

# Add the new layer that we'll be training.
(train_step, cross_entropy, bottleneck_input, ground_truth_input,
   final_tensor) = add_final_training_ops(len(image_lists.keys()),
                                          final_tensor_name,
                                          bottleneck_tensor)

# Create the operations we need to evaluate the accuracy of our new layer.
evaluation_step, prediction = add_evaluation_step(
      final_tensor, ground_truth_input)

# Merge all the summaries and write them out to /tmp/retrain_logs (by default)
merged = tf.summary.merge_all()
train_writer = tf.summary.FileWriter(summaries_dir + '/train',
                                       sess.graph)
validation_writer = tf.summary.FileWriter(summaries_dir + '/validation')

# Set up all our weights to their initial default values.
init = tf.global_variables_initializer()
sess.run(init)

# Run the training for as many cycles as requested on the command line.
for i in range(how_many_training_steps):
    # Get a batch of input bottleneck values, either calculated fresh every time
    # with distortions applied, or from the cache stored on disk.
    if do_distort_images:
        train_bottlenecks, train_ground_truth = get_random_distorted_bottlenecks(
            sess, image_lists, train_batch_size, 'training',
            image_dir, distorted_jpeg_data_tensor,
            distorted_image_tensor, resized_image_tensor, bottleneck_tensor)
    else:
        train_bottlenecks, train_ground_truth, _ = get_random_cached_bottlenecks(
            sess, image_lists, train_batch_size, 'training',
            bottleneck_dir, image_dir, jpeg_data_tensor,
            bottleneck_tensor)
    # Feed the bottlenecks and ground truth into the graph, and run a training
    # step. Capture training summaries for TensorBoard with the `merged` op.
    train_summary, _ = sess.run([merged, train_step],
                                feed_dict={bottleneck_input: train_bottlenecks,
                                           ground_truth_input: train_ground_truth})
    train_writer.add_summary(train_summary, i)

    # Every so often, print out how well the graph is training.
    is_last_step = (i + 1 == how_many_training_steps)
    if (i % eval_step_interval) == 0 or is_last_step:
        train_accuracy, cross_entropy_value = sess.run(
            [evaluation_step, cross_entropy],
            feed_dict={bottleneck_input: train_bottlenecks,
                       ground_truth_input: train_ground_truth})
        print('%s: Step %d: Train accuracy = %.1f%%' % (datetime.now(), i,
                                                      train_accuracy * 100))
        print('%s: Step %d: Cross entropy = %f' % (datetime.now(), i,
                                                 cross_entropy_value))
        validation_bottlenecks, validation_ground_truth, _ = (
            get_random_cached_bottlenecks(
                sess, image_lists, validation_batch_size, 'validation',
                bottleneck_dir, image_dir, jpeg_data_tensor,
                bottleneck_tensor))
        # Run a validation step and capture training summaries for TensorBoard
        # with the `merged` op.
        validation_summary, validation_accuracy = sess.run(
            [merged, evaluation_step],
            feed_dict={bottleneck_input: validation_bottlenecks,
                     ground_truth_input: validation_ground_truth})
        validation_writer.add_summary(validation_summary, i)
        print('%s: Step %d: Validation accuracy = %.1f%% (N=%d)' %
              (datetime.now(), i, validation_accuracy * 100,
               len(validation_bottlenecks)))

# We've completed all our training, so run a final test evaluation on
# some new images we haven't used before.
test_bottlenecks, test_ground_truth, test_filenames = (
    get_random_cached_bottlenecks(sess, image_lists, test_batch_size,
                                  'testing', bottleneck_dir,
                                  image_dir, jpeg_data_tensor,
                                  bottleneck_tensor))
test_accuracy, predictions = sess.run(
    [evaluation_step, prediction],
    feed_dict={bottleneck_input: test_bottlenecks,
               ground_truth_input: test_ground_truth})
print('Final test accuracy = %.1f%% (N=%d)' % (
    test_accuracy * 100, len(test_bottlenecks)))

if print_misclassified_test_images:
    print('=== MISCLASSIFIED TEST IMAGES ===')
    for i, test_filename in enumerate(test_filenames):
        if predictions[i] != test_ground_truth[i].argmax():
            print('%70s  %s' % (test_filename, image_lists.keys()[predictions[i]]))

# Write out the trained graph and labels with the weights stored as constants.
output_graph_def = graph_util.convert_variables_to_constants(
    sess, graph.as_graph_def(), [final_tensor_name])
with gfile.FastGFile(output_graph, 'wb') as f:
    f.write(output_graph_def.SerializeToString())
with gfile.FastGFile(output_labels, 'w') as f:
    f.write('\n'.join(image_lists.keys()) + '\n')
# Out:
# Looking for images in 'mole'
# Looking for images in 'cancer'
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010254_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011165_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011208_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010249_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010063_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010069_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010602_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010220_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009949_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010075_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009933_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009906_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010229_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011402_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010463_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010337_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009935_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010244_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010205_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010467_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010847_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010857_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009962_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010581_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010483_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010374_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011207_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009939_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010222_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010040_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010317_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010569_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010053_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009875_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011326_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010176_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010022_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011224_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010603_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010365_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011083_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010178_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011079_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009968_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010327_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010449_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010574_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011306_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010055_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009921_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010435_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011292_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010104_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010046_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010582_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010854_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011343_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011159_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009912_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010044_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010003_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010255_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010861_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010202_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009964_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010088_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010567_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010062_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010487_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010185_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009872_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010460_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010568_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009895_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009972_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011098_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010074_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009885_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009987_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011162_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009930_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010593_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011088_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010471_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010019_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010498_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009932_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010344_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010332_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010318_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011211_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011170_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011220_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010213_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011203_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010043_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010473_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009923_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010371_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010246_resized_resized.jpg.txt
# 100 bottleneck files created.
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010333_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010206_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010334_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009931_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011127_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009925_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010456_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011358_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010257_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010057_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009873_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009965_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010448_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011398_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011310_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009969_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010020_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011359_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011215_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009954_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009963_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009870_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011115_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010212_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010078_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011225_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010219_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009911_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010864_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009901_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011393_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010093_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010851_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009879_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010442_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009883_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010015_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009920_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009888_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011322_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010598_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010474_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011157_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010193_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010565_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010853_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011397_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010025_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009945_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009961_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010042_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010201_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010058_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011214_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011144_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010192_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011124_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010490_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009973_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010492_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010326_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009951_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011213_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009991_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010051_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010168_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010858_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010461_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010028_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010571_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010455_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011085_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011145_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010477_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011229_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011217_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011330_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010264_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010340_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011107_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010465_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010479_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010497_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010173_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010584_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011362_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009982_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011219_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009914_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010586_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010472_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010237_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010585_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010032_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009917_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011321_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009936_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009943_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011361_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009881_resized_resized.jpg.txt
# 200 bottleneck files created.
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009974_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010846_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010346_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010458_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010447_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010589_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010599_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010444_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011338_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009977_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009967_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009919_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009947_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010184_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009966_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010060_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011352_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009941_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010021_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011328_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011167_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010059_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010351_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009937_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011386_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010006_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010262_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010215_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010488_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010367_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009938_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010236_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010562_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011143_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010557_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010186_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011155_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010848_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010070_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011304_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011097_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011367_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011168_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010330_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011336_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010256_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011296_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010493_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011199_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009891_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011324_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011353_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011339_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010061_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010588_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009902_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010844_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010336_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009899_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010481_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010607_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011345_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009877_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010216_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009874_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010494_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011146_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011294_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011212_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009976_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011327_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010013_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009869_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010357_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010475_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010092_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011171_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009929_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011110_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010368_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011297_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010382_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010234_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010341_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010182_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011164_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010480_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009909_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010552_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010362_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010443_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011082_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009956_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010558_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009979_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009975_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010850_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009942_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009871_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011317_resized_resized.jpg.txt
# 300 bottleneck files created.
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010090_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010064_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010342_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011218_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009896_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011333_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009998_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010047_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010575_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010570_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010018_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010554_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011303_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010191_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010370_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009981_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011123_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010573_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010187_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010566_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010856_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010014_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011298_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009994_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011089_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010452_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011101_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009889_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010180_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010553_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011131_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010320_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011090_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011119_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010595_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010590_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011347_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010005_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010348_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011205_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011114_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010102_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010100_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010339_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010356_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009946_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009940_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010017_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011227_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010247_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011363_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009880_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009884_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011204_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011230_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011117_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011223_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010592_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009958_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011102_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011300_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010087_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011173_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010002_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011382_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010105_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009953_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0011177_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010233_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010606_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010248_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010066_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010227_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0009915_resized_resized.jpg.txt
# Creating bottleneck at sk_bottlenecks/mole/ISIC_0010261_resized_resized.jpg.txt
# 400 bottleneck files created.
# 2017-11-12 15:28:45.480951: Step 0: Train accuracy = 77.0%
# 2017-11-12 15:28:45.481085: Step 0: Cross entropy = 0.683066
# 2017-11-12 15:28:45.579624: Step 0: Validation accuracy = 46.0% (N=100)
# 2017-11-12 15:28:45.911841: Step 10: Train accuracy = 54.0%
# 2017-11-12 15:28:45.911913: Step 10: Cross entropy = 0.655050
# 2017-11-12 15:28:45.945911: Step 10: Validation accuracy = 50.0% (N=100)
# 2017-11-12 15:28:46.270596: Step 20: Train accuracy = 53.0%
# 2017-11-12 15:28:46.270681: Step 20: Cross entropy = 0.657973
# 2017-11-12 15:28:46.303562: Step 20: Validation accuracy = 51.0% (N=100)
# 2017-11-12 15:28:46.630365: Step 30: Train accuracy = 64.0%
# 2017-11-12 15:28:46.630437: Step 30: Cross entropy = 0.617406
# 2017-11-12 15:28:46.661906: Step 30: Validation accuracy = 55.0% (N=100)
# 2017-11-12 15:28:46.988600: Step 40: Train accuracy = 57.0%
# 2017-11-12 15:28:46.988667: Step 40: Cross entropy = 0.692086
# 2017-11-12 15:28:47.020809: Step 40: Validation accuracy = 62.0% (N=100)
# 2017-11-12 15:28:47.351243: Step 50: Train accuracy = 72.0%
# 2017-11-12 15:28:47.351309: Step 50: Cross entropy = 0.564040
# 2017-11-12 15:28:47.383618: Step 50: Validation accuracy = 65.0% (N=100)
# 2017-11-12 15:28:47.731656: Step 60: Train accuracy = 76.0%
# 2017-11-12 15:28:47.731724: Step 60: Cross entropy = 0.537766
# 2017-11-12 15:28:47.767591: Step 60: Validation accuracy = 67.0% (N=100)
# 2017-11-12 15:28:48.120692: Step 70: Train accuracy = 79.0%
# 2017-11-12 15:28:48.120770: Step 70: Cross entropy = 0.547355
# 2017-11-12 15:28:48.154046: Step 70: Validation accuracy = 64.0% (N=100)
# 2017-11-12 15:28:48.514008: Step 80: Train accuracy = 72.0%
# 2017-11-12 15:28:48.514074: Step 80: Cross entropy = 0.564259
# 2017-11-12 15:28:48.549176: Step 80: Validation accuracy = 63.0% (N=100)
# 2017-11-12 15:28:48.906201: Step 90: Train accuracy = 71.0%
# 2017-11-12 15:28:48.906276: Step 90: Cross entropy = 0.542408
# 2017-11-12 15:28:48.941397: Step 90: Validation accuracy = 61.0% (N=100)
# 2017-11-12 15:28:49.303327: Step 100: Train accuracy = 76.0%
# 2017-11-12 15:28:49.303394: Step 100: Cross entropy = 0.528366
# 2017-11-12 15:28:49.336994: Step 100: Validation accuracy = 61.0% (N=100)
# 2017-11-12 15:28:49.679799: Step 110: Train accuracy = 74.0%
# 2017-11-12 15:28:49.679962: Step 110: Cross entropy = 0.534095
# 2017-11-12 15:28:49.712730: Step 110: Validation accuracy = 60.0% (N=100)
# 2017-11-12 15:28:50.044637: Step 120: Train accuracy = 86.0%
# 2017-11-12 15:28:50.044708: Step 120: Cross entropy = 0.459858
# 2017-11-12 15:28:50.079503: Step 120: Validation accuracy = 56.0% (N=100)
# 2017-11-12 15:28:50.409051: Step 130: Train accuracy = 79.0%
# 2017-11-12 15:28:50.409120: Step 130: Cross entropy = 0.484151
# 2017-11-12 15:28:50.440780: Step 130: Validation accuracy = 60.0% (N=100)
# 2017-11-12 15:28:50.768345: Step 140: Train accuracy = 76.0%
# 2017-11-12 15:28:50.768464: Step 140: Cross entropy = 0.498918
# 2017-11-12 15:28:50.799223: Step 140: Validation accuracy = 71.0% (N=100)
# 2017-11-12 15:28:51.133144: Step 150: Train accuracy = 69.0%
# 2017-11-12 15:28:51.133212: Step 150: Cross entropy = 0.534715
# 2017-11-12 15:28:51.164512: Step 150: Validation accuracy = 65.0% (N=100)
# 2017-11-12 15:28:51.490048: Step 160: Train accuracy = 78.0%
# 2017-11-12 15:28:51.490114: Step 160: Cross entropy = 0.470030
# 2017-11-12 15:28:51.523065: Step 160: Validation accuracy = 64.0% (N=100)
# 2017-11-12 15:28:51.847485: Step 170: Train accuracy = 86.0%
# 2017-11-12 15:28:51.847552: Step 170: Cross entropy = 0.452507
# 2017-11-12 15:28:51.878861: Step 170: Validation accuracy = 63.0% (N=100)
# 2017-11-12 15:28:52.204225: Step 180: Train accuracy = 75.0%
# 2017-11-12 15:28:52.204291: Step 180: Cross entropy = 0.470006
# 2017-11-12 15:28:52.237104: Step 180: Validation accuracy = 53.0% (N=100)
# 2017-11-12 15:28:52.561557: Step 190: Train accuracy = 75.0%
# 2017-11-12 15:28:52.561622: Step 190: Cross entropy = 0.490594
# 2017-11-12 15:28:52.594333: Step 190: Validation accuracy = 57.0% (N=100)
# 2017-11-12 15:28:52.919199: Step 200: Train accuracy = 79.0%
# 2017-11-12 15:28:52.919266: Step 200: Cross entropy = 0.468556
# 2017-11-12 15:28:52.951218: Step 200: Validation accuracy = 66.0% (N=100)
# 2017-11-12 15:28:53.282438: Step 210: Train accuracy = 83.0%
# 2017-11-12 15:28:53.282505: Step 210: Cross entropy = 0.435560
# 2017-11-12 15:28:53.315751: Step 210: Validation accuracy = 61.0% (N=100)
# 2017-11-12 15:28:53.664627: Step 220: Train accuracy = 77.0%
# 2017-11-12 15:28:53.664698: Step 220: Cross entropy = 0.473376
# 2017-11-12 15:28:53.698837: Step 220: Validation accuracy = 61.0% (N=100)
# 2017-11-12 15:28:54.045814: Step 230: Train accuracy = 80.0%
# 2017-11-12 15:28:54.045929: Step 230: Cross entropy = 0.454813
# 2017-11-12 15:28:54.078218: Step 230: Validation accuracy = 56.0% (N=100)
# 2017-11-12 15:28:54.418869: Step 240: Train accuracy = 83.0%
# 2017-11-12 15:28:54.418937: Step 240: Cross entropy = 0.409882
# 2017-11-12 15:28:54.453421: Step 240: Validation accuracy = 53.0% (N=100)
# 2017-11-12 15:28:54.797876: Step 250: Train accuracy = 87.0%
# 2017-11-12 15:28:54.797997: Step 250: Cross entropy = 0.390126
# 2017-11-12 15:28:54.835386: Step 250: Validation accuracy = 70.0% (N=100)
# 2017-11-12 15:28:55.165330: Step 260: Train accuracy = 92.0%
# 2017-11-12 15:28:55.165417: Step 260: Cross entropy = 0.339934
# 2017-11-12 15:28:55.198132: Step 260: Validation accuracy = 49.0% (N=100)
# 2017-11-12 15:28:55.525889: Step 270: Train accuracy = 81.0%
# 2017-11-12 15:28:55.525956: Step 270: Cross entropy = 0.411284
# 2017-11-12 15:28:55.558166: Step 270: Validation accuracy = 62.0% (N=100)
# 2017-11-12 15:28:55.882423: Step 280: Train accuracy = 84.0%
# 2017-11-12 15:28:55.882488: Step 280: Cross entropy = 0.440760
# 2017-11-12 15:28:55.913744: Step 280: Validation accuracy = 43.0% (N=100)
# 2017-11-12 15:28:56.239022: Step 290: Train accuracy = 80.0%
# 2017-11-12 15:28:56.239088: Step 290: Cross entropy = 0.405581
# 2017-11-12 15:28:56.270417: Step 290: Validation accuracy = 73.0% (N=100)
# 2017-11-12 15:28:56.599423: Step 300: Train accuracy = 89.0%
# 2017-11-12 15:28:56.599557: Step 300: Cross entropy = 0.356851
# 2017-11-12 15:28:56.634443: Step 300: Validation accuracy = 70.0% (N=100)
# 2017-11-12 15:28:56.981274: Step 310: Train accuracy = 86.0%
# 2017-11-12 15:28:56.981342: Step 310: Cross entropy = 0.375300
# 2017-11-12 15:28:57.017336: Step 310: Validation accuracy = 56.0% (N=100)
# 2017-11-12 15:28:57.362040: Step 320: Train accuracy = 86.0%
# 2017-11-12 15:28:57.362132: Step 320: Cross entropy = 0.385671
# 2017-11-12 15:28:57.395478: Step 320: Validation accuracy = 61.0% (N=100)
# 2017-11-12 15:28:57.738881: Step 330: Train accuracy = 87.0%
# 2017-11-12 15:28:57.738957: Step 330: Cross entropy = 0.407131
# 2017-11-12 15:28:57.773031: Step 330: Validation accuracy = 70.0% (N=100)
# 2017-11-12 15:28:58.119619: Step 340: Train accuracy = 86.0%
# 2017-11-12 15:28:58.119736: Step 340: Cross entropy = 0.371787
# 2017-11-12 15:28:58.152712: Step 340: Validation accuracy = 68.0% (N=100)
# 2017-11-12 15:28:58.494106: Step 350: Train accuracy = 90.0%
# 2017-11-12 15:28:58.494241: Step 350: Cross entropy = 0.369346
# 2017-11-12 15:28:58.529628: Step 350: Validation accuracy = 57.0% (N=100)
# 2017-11-12 15:28:58.872746: Step 360: Train accuracy = 86.0%
# 2017-11-12 15:28:58.872822: Step 360: Cross entropy = 0.405485
# 2017-11-12 15:28:58.908925: Step 360: Validation accuracy = 68.0% (N=100)
# 2017-11-12 15:28:59.242238: Step 370: Train accuracy = 87.0%
# 2017-11-12 15:28:59.242442: Step 370: Cross entropy = 0.374754
# 2017-11-12 15:28:59.274417: Step 370: Validation accuracy = 57.0% (N=100)
# 2017-11-12 15:28:59.602435: Step 380: Train accuracy = 88.0%
# 2017-11-12 15:28:59.602507: Step 380: Cross entropy = 0.363485
# 2017-11-12 15:28:59.634414: Step 380: Validation accuracy = 62.0% (N=100)
# 2017-11-12 15:28:59.967474: Step 390: Train accuracy = 90.0%
# 2017-11-12 15:28:59.967541: Step 390: Cross entropy = 0.320964
# 2017-11-12 15:28:59.999650: Step 390: Validation accuracy = 65.0% (N=100)
# 2017-11-12 15:29:00.333785: Step 400: Train accuracy = 92.0%
# 2017-11-12 15:29:00.333850: Step 400: Cross entropy = 0.344784
# 2017-11-12 15:29:00.365214: Step 400: Validation accuracy = 67.0% (N=100)
# 2017-11-12 15:29:00.699412: Step 410: Train accuracy = 87.0%
# 2017-11-12 15:29:00.699479: Step 410: Cross entropy = 0.363785
# 2017-11-12 15:29:00.731168: Step 410: Validation accuracy = 62.0% (N=100)
# 2017-11-12 15:29:01.058212: Step 420: Train accuracy = 92.0%
# 2017-11-12 15:29:01.058281: Step 420: Cross entropy = 0.398739
# 2017-11-12 15:29:01.091554: Step 420: Validation accuracy = 64.0% (N=100)
# 2017-11-12 15:29:01.422972: Step 430: Train accuracy = 94.0%
# 2017-11-12 15:29:01.423038: Step 430: Cross entropy = 0.343318
# 2017-11-12 15:29:01.455278: Step 430: Validation accuracy = 65.0% (N=100)
# 2017-11-12 15:29:01.789522: Step 440: Train accuracy = 83.0%
# 2017-11-12 15:29:01.789589: Step 440: Cross entropy = 0.395164
# 2017-11-12 15:29:01.821470: Step 440: Validation accuracy = 58.0% (N=100)
# 2017-11-12 15:29:02.151283: Step 450: Train accuracy = 83.0%
# 2017-11-12 15:29:02.151347: Step 450: Cross entropy = 0.410624
# 2017-11-12 15:29:02.182951: Step 450: Validation accuracy = 67.0% (N=100)
# 2017-11-12 15:29:02.520988: Step 460: Train accuracy = 90.0%
# 2017-11-12 15:29:02.521058: Step 460: Cross entropy = 0.346745
# 2017-11-12 15:29:02.553426: Step 460: Validation accuracy = 63.0% (N=100)
# 2017-11-12 15:29:02.894110: Step 470: Train accuracy = 91.0%
# 2017-11-12 15:29:02.894181: Step 470: Cross entropy = 0.347318
# 2017-11-12 15:29:02.926194: Step 470: Validation accuracy = 64.0% (N=100)
# 2017-11-12 15:29:03.254785: Step 480: Train accuracy = 87.0%
# 2017-11-12 15:29:03.254850: Step 480: Cross entropy = 0.350244
# 2017-11-12 15:29:03.286314: Step 480: Validation accuracy = 67.0% (N=100)
# 2017-11-12 15:29:03.611799: Step 490: Train accuracy = 95.0%
# 2017-11-12 15:29:03.611866: Step 490: Cross entropy = 0.336010
# 2017-11-12 15:29:03.644812: Step 490: Validation accuracy = 56.0% (N=100)
# 2017-11-12 15:29:03.945461: Step 499: Train accuracy = 92.0%
# 2017-11-12 15:29:03.945529: Step 499: Cross entropy = 0.345509
# 2017-11-12 15:29:03.976597: Step 499: Validation accuracy = 70.0% (N=100)
# Final test accuracy = 75.7% (N=37)
# INFO:tensorflow:Froze 2 variables.
# Converted 2 variables to const ops.
